# %% [markdown]
# ## 课后测试一

# %% [markdown]
# ### 选择题
#
# 1. 在Python中，用于判断条件是否成立的关键字是：A
#
#    a) if
#
#    b) else
#
#    c) while
#
#    d) for
#
# 2. 下面哪个是Python中的循环语句？C
#
#    a) if
#
#    b) else
#
#    c) while
#
#    d) def
#
# 3. 以下哪个关键字可以跳出当前循环并继续下一次循环？B
#
#    a) break
#
#    b) continue
#
#    c) pass
#
#    d) return
#
# 4. 下面哪个是Python中的定义函数的关键字？D
#
#    a) function
#
#    b) define
#
#    c) func
#
#    d) def
#
# 5. 下面哪些是Python中的数据类型？(多选)ABCD
#
#    a) str
#
#    b) int
#
#    c) floats
#
#    d) string

# %% [markdown]
# ### 判断题
#
# 1. 在Python中，使用缩进来表示代码块的开始和结束。
#    a) True
#    b) False
#
#    B,缩进表示的是代码的层级关系。
#
# 2. 下面的代码片段中，if条件成立时，else语句块会执行。B
#    ```python
#    if condition:
#        # code block
#    else:
#        # code block
#    ```
#
#    a) True
#
#    b) False
#
#
# 3. 在Python中，函数必须有参数。A
#
#    a) True
#
#    b) False
#
# ### 填空题
#
# 1. 完成下面的代码，实现一个函数 `add_numbers`，接受两个参数 `a` 和 `b`，返回它们的和。
#    ```python
#    def add_numbers(a, b):
#        # TODO: 完成函数实现
#        return = a + b
#        pass
#
#    # TODO: 调用函数，计算 5 + 10的和
#    pass
#    ```
#    def add_numbers(5,10)
#
# 2. 填写下面的代码，使用 while 循环计算从 100 到 900 整百的累加和，并将结果存储在变量 `total` 中。
#    ```python
#
#
#        # TODO: 完成代码
#
# total = 0
# i = 100
# while i <= 900:
#     total +=i
#     i +=100
# print(total)   ```
#
#
# ### 代码改错
#
# 1. 下面的代码有一个错误，请找出并修改：(没找出来）
#    ```python
#    for i in range(1, 5)：
#        print(i)
#    ```
#
# 2. 下面的代码有三处错误，请找出并修改，并写出最终的运算结果。（代码块写在下面了）
#
#     ```python
#     # 判断一个自然数是否素数
#     def isPrime(a)
#         if a == 1 or a == 2:
#             return False
#         for i in range(2, a):
#             if a % i = 0:
#                 return True
#         return False
#
#     # 请输入一个整数
#     n = int(input("请输入一个整数:"))
#
#     if isPrime(n):
#         print(f"{n} 是素数")
#     else:
#     print(f"{n} 不是素数")
#
#     ```
#
#
#
# ### 编程题
#
#
# 1. 编写一个函数 `multiply_table`，接受一个正整数作为参数，打印出该数字的乘法表。例如，当参数为 5 时，输出如下：
#     ```
#     1 * 1 = 1
#     1 * 2 = 2
#     1 * 3 = 3
#     ...
#     5 * 10 = 50
#     ```

# %%
 # 代码改错第二题，判断是否为素数
    def isPrime(a)
        if a == 1 or a == 2:
            return False
        for i in range(2, a):
            if a % i = 0:
                return True
        return False
    
    # 请输入一个整数
    n = int(input("请输入一个整数:"))
    
    if isPrime(n):
        print(f"{n} 是素数")
    else:
    print(f"{n} 不是素数")

# %%
"""编写一个函数 multiply_table，接受一个正整数作为参数，打印出该数字的乘法表。例如，当参数为 5 时，输出如下：
1 * 1 = 1
1 * 2 = 2
1 * 3 = 3
...
5 * 10 = 50
"""

a = int(input("请输入一个正整数："))
for c in range (1,a+1):
    for b in range (1,11):
        print(f"{c}*{b}={c*b}")
